# %% [markdown]
# # Assignment 2
# #### DATA 690 python-stats-dataviz
#
# This asssignment asks us to write some code that will:
#
# 1. Ask the user to input 10 numbers
#     - The numbers should be **integers**
#     - if the user enters _anything_ other than an integer allow the user to retry while still collecting all 10 numbers
#
#
# 2. The following mathematical operations should be preformed:
#     - Minimum
#     - Maximum
#     - Range
#     - Mean
#     - Variance
#     - Standard Deviation
#
#
# 3. Output results to the user.

# %% [markdown]
# ## The Code
#
# ### Constants
#
# **LIST_SIZE**: this constant controls how many numbers the user should input

# %%
# Constants
LIST_SIZE = 10

# %% [markdown]
# ### Functions
# These are all the functions used in the code
#
# **get_data()**: processes user input and ensures that it is constrained to the number set in the constansts section
#
# **get_sum()**: used to calculate the sum from the user's input
#
# **get_variance()**: used to calculate the variance from the user's input

# %%
def get_data():
  a_list = []

  count = len(a_list)

  while count < LIST_SIZE:
    
    print (f'\nIt look\'s like we still need {LIST_SIZE - count} out of {LIST_SIZE} numbers to complete the set.')
    usr_input = input('\nPlease enter a whole number: ')
    
    try:
      usr_input = int(usr_input)
      a_list.append(usr_input)
      count = len(a_list)
      print (f'Thanks for entering {usr_input}, I\'m adding it to your set for safe keeping.')  

    except:
      print(f'Uh oh! it look\'s like you entered {usr_input}, that\'s not a whole number. But that\'s okay, please try again.')

  return a_list

def get_sum(some_list):
  some_sum = 0
  for num in some_list:
    some_sum += num
  return some_sum

def get_variance(some_list):
  some_sum = 0
  for num in some_list:
    some_sum += num**2
  return some_sum

# %% [markdown]
# ### Request User Input Data
#
# The following block of code requests the user input numbers that will will be stored as a list in a variable _usr\_list_
#
# also, stores the sum  of the list and sorts the numbers in the list so all the mathematical operations can be computed.

# %%
print(f'HI! I\'m a program. I preform mathematical operations. To get me to run I need you enter a set consisting of {LIST_SIZE} numbers, then I\'ll calculate the following operations for you: \n\nMinimum \nMaximum \nRange \nMean \nVariance \nStandard Deviation')

# prepare data to be used in mathematical operations
usr_list = get_data()
usr_sum = get_sum(usr_list)
usr_list.sort() # sorts the data numerically from lowest to highest value
# Out:
# HI! I'm a program. I preform mathematical operations. To get me to run I need you enter a set consisting of 10 numbers, then I'll calculate the following operations for you:
#
# Minimum
# Maximum
# Range
# Mean
# Variance
# Standard Deviation
#
# It look's like we still need 10 out of 10 numbers to complete the set.
# Thanks for entering 10, I'm adding it to your set for safe keeping.
#
# It look's like we still need 9 out of 10 numbers to complete the set.
# Uh oh! it look's like you entered o, that's not a whole number. But that's okay, please try again.
#
# It look's like we still need 9 out of 10 numbers to complete the set.
# Uh oh! it look's like you entered 89.3, that's not a whole number. But that's okay, please try again.
#
# It look's like we still need 9 out of 10 numbers to complete the set.
# Thanks for entering 5, I'm adding it to your set for safe keeping.
#
# It look's like we still need 8 out of 10 numbers to complete the set.
# ...

# %% [markdown]
# ### Mathematical Operations
#
# All the operations below will be computed and stored in the named variables

# %%
# Minimum 
usr_min = usr_list[0]

# Maximum 
usr_max = usr_list[-1]

# Range (the difference between lowest and highest values)
usr_range = usr_max - usr_min

# Mean (sum of all values in a set divided by the number of values)
usr_mean = usr_sum / len(usr_list)

# Variance (all values squared and then take their sum)
usr_variance = get_variance(usr_list)

# Standard Deviation (square root of variance)
usr_std_dev = usr_variance**.5

# %% [markdown]
# ### Output Calculations
# prints the results of all the operations for the user to view

# %%
# print the results out to the console for the user to view
result = f'''\n\nBeep boop beep brrzt. I calculated several mathematical operations based on your entries, {usr_list} they are displayed below: \n\nMinimum: {usr_min}  \nMaximum: {usr_max}  \nRange: {usr_range} \nMean: {usr_mean} \nVariance: {usr_variance} \nStandard Deviation {usr_std_dev}'''
print(result)
# Out:
# Beep boop beep brrzt. I calculated several mathematical operations based on your entries, [1, 5, 9, 10, 345, 437, 532, 956, 234543, 234723] they are displayed below:
#
# Minimum: 1
# Maximum: 234723
# Range: 234722
# Mean: 47156.1
# Variance: 110106812739
# Standard Deviation 331823.4662271492

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b26b1a57-aeca-483f-a072-04fd316a6947' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
